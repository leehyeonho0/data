# %% [markdown]
# ### 전자신문 뉴스 헤드라인과 상세내용

# %%
#!pip install beautifulsoup4

# %%
import os, re, csv
import requests # URL 주소에 있는 내용을 요청할 때 사용하는 모듈
import urllib.request as ur  # 웹에서 얻은 데이터를 다루는 파이썬 패키지
from bs4 import BeautifulSoup as bs

# %%
news = 'https://www.etnews.com/news/hot_content_list.html'
soup = bs(ur.urlopen(news).read(), 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>전자신문</title>
# <meta content="width=device-width" name="viewport"/>
# <meta content="-1" http-equiv="Expires">
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!--[if IE]><meta http-equiv='X-UA-Compatible' content='IE=edge,chrome=1'><![endif]-->
# <meta content="all" name="robots">
# <meta content="www.etnews.com" name="author"/>
# <meta content="Copyright © Electronic Times Internet. All Right Reserved." name="copyright"/>
# <meta content="전자신문,전자신문인터넷,Etnews,Etnews.com,뉴스,News,속보,방송,연예,통신,SW,바이오,소재,부품,과학,전자,자동차,경제,금융,산업,정책,글로벌,리포트,동영상," name="keywords"/>
# <meta content="대한민국을 대표하는 IT 전문 뉴스포털 전자신문" name="description"/>
# <meta content="1425291491111655" property="fb:app_id"/>
# <meta content="telephone=no" name="format-detection"/>
# ...

# %%
quote = soup.find_all('ul', {"class":"list_news"})
quote
# Out:
# [<ul class="list_news">
#  <li>
#  <dl class="clearfix">
#  <dt><a href="//www.etnews.com/20210215000207">현대차 '통큰 결단'...전기차 '코나 7만7000대' 배터리 전량 교체</a></dt>
#  <dd class="thumb"><a href="//www.etnews.com/20210215000207"><img alt="현대차 \'통큰 결단\'...전기차 \'코나 7만7000대\' 배터리 전량 교체" src="https://img.etnews.com/news/article/2021/02/15/article_15165820603142.png"/></a></dd>
#  <dd class="summury"><a href="//www.etnews.com/20210215000207">현대차가 잇따른 차량 화재로 골머리를 앓아 온 전기차 코나 일렉트릭의 배터리를 전량 교체하는 쪽으로 가닥을 잡았다. 투입 비용만 1조원이 넘는다. 이번 달 국토교통부의 사고 원인 조사...</a></dd>
#  <dd class="date"><span>박태준</span><span>2021.02.15 15:42:00</span></dd>
#  </dl>
#  </li>
#  <li>
#  <dl class="clearfix">
#  <dt><a href="//www.etnews.com/20210215000221">애플, LGD와 '폴더블 아이폰' 내놓는다</a></dt>
#  <dd class="thumb"><a href="//www.etnews.com/20210215000221"><img alt="애플, LGD와 \'폴더블 아이폰\' 내놓는다" src="https://img.etnews.com/photonews/2102/1384162_20210215163324_651i.jpg"/></a></dd>
# ...

# %%
newsoup = soup.find_all('dt')[8:]
for i in newsoup:
    print(i.text)
# Out:
# 현대차 '통큰 결단'...전기차 '코나 7만7000대' 배터리 전량 교체
# 애플, LGD와 '폴더블 아이폰' 내놓는다
# 항우연, 다단연소 사이클 엔진 개발 본격화...2027년 개량형 기체 적용
# 자율주행 '무인 상점' 농촌·산간 곳곳 누빈다
# 삼성 정수기 내달 출시…시장 판도 흔들까
# 전기차·자율차로 진격하는 스마트폰 부품사들
# 테슬라 '모델 Y' 국내 출시…가격은 5999만원부터
# 日 지진에 르네사스 공장 가동 중단...車반도체 공급난 악화 우려
# 공공 클라우드 1조 시대 열린다...마중물 역할 '톡톡'

# %%
# get으로 href 속성값 구하기
# URL 주소를 추출
for i in newsoup :
    print(i.find_all('a')[0].get('href'))
# Out:
# //www.etnews.com/20210215000207
# //www.etnews.com/20210215000221
# //www.etnews.com/20210215000057
# //www.etnews.com/20210214000077
# //www.etnews.com/20210209000222
# //www.etnews.com/20210214000024
# //www.etnews.com/20210212000009
# //www.etnews.com/20210215000243
# //www.etnews.com/20210214000081

# %%
# 웹 문서를 뷰티풀수프 객체에 저장하기
article1 = 'https:' + '//www.etnews.com/20210215000207'
soup2 = bs(ur.urlopen(article1).read(), 'html.parser')
soup2
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>현대차 '통큰 결단'...전기차 '코나 7만7000대' 배터리 전량 교체 - 전자신문</title>
# <meta content="width=device-width" name="viewport"/>
# <meta content="-1" http-equiv="Expires">
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!--[if IE]><meta http-equiv='X-UA-Compatible' content='IE=edge,chrome=1'><![endif]-->
# <meta content="all" name="robots">
# <meta content="www.etnews.com" name="author"/>
# <meta content="Copyright © Electronic Times Internet. All Right Reserved." name="copyright"/>
# <meta content="전자신문,전자신문인터넷,Etnews,Etnews.com,뉴스,News,속보,방송,연예,통신,SW,바이오,소재,부품,과학,전자,자동차,경제,금융,산업,정책,글로벌,리포트,동영상, 화재,배터리,자동차,전기차,코나,현대차,LG솔루션,LG화학" name="keywords"/>
# <meta content="대한민국을 대표하는 IT 전문 뉴스포털 전자신문" name="description"/>
# ...

# %%
#기사 본문 가져오기
for i in soup2.find_all('section', {"class":"article_body"}): 
    print(i.text)
# Out:
# 1조원 투입...리콜 최대 규모국토부 조사결과 발표 등 고려LG에너지솔루션과 비용 분담
# ...

# %%
# 제목을 출력할때 마다 해당 기사의 내용을 함께 출력한다.
for i in newsoup:  # headline 객체에서 <div> 태그를 하나씩 가져온다.
    print(i.text, '\n') # 기사제목을 출력한다.
    
    #  해당 기사가 올라와 있는 웹 사이트를 열어 soup 객체에 저장한다.    
    article1 = 'https:' + i.find_all('a')[0].get('href')
    soup = bs(ur.urlopen(article1).read(), 'html.parser')  
    
    for j in soup.find_all('section', {"class":"article_body"}): # <p> 태그에서 텍스트만 출력한다.
        print(j.text)
# Out:
# 현대차 '통큰 결단'...전기차 '코나 7만7000대' 배터리 전량 교체
#
#
# 1조원 투입...리콜 최대 규모국토부 조사결과 발표 등 고려LG에너지솔루션과 비용 분담
# ...

# %%
import pandas as pd

# %%
title = []
content = []
# 제목을 출력할때 마다 해당 기사의 내용을 함께 출력한다.
for i in newsoup:  # headline 객체에서 <div> 태그를 하나씩 가져온다.
    title.append(i.text) # 기사제목을 저장한다.
    
    #  해당 기사가 올라와 있는 웹 사이트를 열어 soup 객체에 저장한다.    
    article1 = 'https:' + i.find_all('a')[0].get('href')
    soup = bs(ur.urlopen(article1).read(), 'html.parser')  
    
    for j in soup.find_all('section', {"class":"article_body"}): # <p> 태그에서 텍스트만 출력한다.
        content.append(j.text) # 기사 내용을 저장한다.
articles = {'기사제목' : title,
            '기사내용' : content}

# %%
etnews = pd.DataFrame.from_dict(articles)
etnews.head()
# Out:
#                                         기사제목  \
# 0   현대차 '통큰 결단'...전기차 '코나 7만7000대' 배터리 전량 교체
# 1                    애플, LGD와 '폴더블 아이폰' 내놓는다
# 2  항우연, 다단연소 사이클 엔진 개발 본격화...2027년 개량형 기체 적용
# 3                  자율주행 '무인 상점' 농촌·산간 곳곳 누빈다
# 4                     삼성 정수기 내달 출시…시장 판도 흔들까
#
#                                                 기사내용
# 0  \n1조원 투입...리콜 최대 규모국토부 조사결과 발표 등 고려LG에너지솔루션과 비...
# 1  \n자사 특허 디스플레이 개발 위탁차별화된 '폴딩' 기술 구현 전망LGD, 중소형 ...
# 2  \n버려지던 가스, 연소기로 다시 태워기존 사이클 대비 10% 높은 성능 보유\n한...
# 3  \n산업부, 26일까지 기술개발 업체 공모올해 289억 등 2024년까지 지속 투자...
# 4  \nAI 기술 적용한 직수형 언더싱크 제품렌털 대신 전국 대리점 직접 판매키로비스포...

# %%
etnews.to_excel("etnews.xlsx", index=False)
