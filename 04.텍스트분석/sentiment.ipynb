# %% [markdown]
# ## 감정분석
# - 감정 또는 감성(sentiment)
# - 텍스트에 나타난 긍정/부정의 태도
# - 기계학습 방식과 사전 방식
#
# ### 감정사전
# - 긍정 표현, 부정 표현의 사전
# - 해당 분야 전문가가 있으면 데이터 없이도 만들 수 있음
# - 기계학습으로도 개발 가능

# %% [markdown]
# ## 네이버 영화평
#
# - 네이버 영화에서 분석하고 싶은 영화 페이지로 들어감
# - 네티즌 별점 클릭
# - 페이지 번호 우클릭 후 주소 복사

# %%
# https://movie.naver.com/movie/bi/mi/point.nhn?code=190382 
# ( https://movie.naver.com ) + ( 검사 -> iframe src 부분 복사) + ( &page={} )
url = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=190382&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page={}'

# %% [markdown]
# 리뷰 수집

# %%
import requests
import lxml.html
import re # 정규표현식을 쓰겠다

# 리뷰와 별점을 모을 빈 리스트를 만든다
reviews = []
scores = []

for page in range(1, 30):  # 1~29페이지까지 반복
    res = requests.get(url.format(page))  # 각 페이지에 접속한다
    root = lxml.html.fromstring(res.text)  # html을 처리한다

    # 리뷰를 가져와 reviews에 추가한다
    for review in root.cssselect('.score_reple p'):
        # 한글, 알파벳, 숫자를 제외한 문자를 제거
        review_trans = re.sub(r'[^가-힣A-z0-9]+', ' ', review.text_content())
        print(review_trans)
        reviews.append(review_trans)

    # 별점을 가져와 scores에 추가한다
    for score in root.cssselect('.score_result .star_score em'):
        scores.append(int(score.text_content()))
        #print(int(score.text_content()))
# Out:
#  관람객 그냥 모르겠다 돈 아깝다
#  관람객 나도 모르는 사이에 작년에 많이 힘들었나봐요 카운트다운할때 울컥해요 올해는 좋은 일만 있었으면 좋겠어요 힐링되는 영화입니다
#  관람객 손발사라지는줄 오글
#  관람객 아르헨티나 장면들 힐링 2021년에는 행복한 일만 가득했으면
#  관람객 간만에 극장에서 힐링받고 간다 이건 연인들 뿐만 아니라 가족 친구와 봐도 힐링각
#  관람객 설레고 따뜻한 영화였음 친구나 가족이랑 보기 좋음
#  관람객 유연석배우님 보려고 봤는데 다른 배우분들 연기랑 케미도 너무 좋았어요 그리고 이거 보고 제 버킷리스트에 비행기에서 해피뉴이어 해보는거 적어놨어요 오랜만에 힐링 되는 영화 본거 같네용 아무튼 유연석 쎄게 사
#  관람객 남자친구랑 보기 딱 좋은 영화 커플이라면 100 공감할 이야기인것 같아요
#  관람객 이 배우들을 언제 다시 한 영화에서 보나 싶네요 설레기도 하고 지금 하지 못하는 것들을 보면서 힐링도 되고 연휴에 누구나 같이 보기 좋은 영화입니다
#  관람객 오랜만에 극장에서 편하게 본 영화 예전에는 해외 여행도 자유롭게 갔는데
#  관람객 솔직히 말씀 드리자면 다 괜찮았는데 이연희씨 연기가 아쉬웠습니다 사람마다 개개인의 차이가 있어 할말은 아니지만 저는 개인적으로 영화에 집중하기 어려웠습니다
#  관람객 이런 심난한 시국에 단비같은 영화네요 힐링시간이었습니다
#  관람객 간만에 진짜 힐링되는 영화 배우들도 많이 나와서 너무 좋았어요 친구들이랑 보기에도 너무 좋아요
#  관람객 연애세포 살리기 딱 좋아요 따로따로인듯 같이 융화되는게 재밌었어요
#  관람객 정말 힐링되고 좋은영화 입니다 배우들이 모두 최고예요 보는내내 너무 좋았어요
#  관람객 보는 내내 달콤했습니다 뭔가 환상같으면서도 현실적은 사랑들이 멀지 않게 느껴지기도 햇던
#  관람객 좋아하는 배우들이 대거 출연하여 기대가 컸음에도 그 기대를 부흥해주어 너무 감사합니다 작년 한해 생활이 사라진 모두를 위한 힐링영화네요 추천드려요
#  쪼끔 지루하지만 볼만한 영화
#  영화는 쏘쏘함이연희씨 연기만 좀더 잘하셨으면

# %% [markdown]
# 표 만들기

# %%
import pandas as pd

df = pd.DataFrame({
    'score': scores, 
    'review': reviews
})

# %%
df.head()
# Out:
#    score                                             review
# 0      1                                 관람객 그냥 모르겠다 돈 아깝다
# 1     10   관람객 나도 모르는 사이에 작년에 많이 힘들었나봐요 카운트다운할때 울컥해요 올해는...
# 2      3                                    관람객 손발사라지는줄 오글
# 3     10             관람객 아르헨티나 장면들 힐링 2021년에는 행복한 일만 가득했으면
# 4     10   관람객 간만에 극장에서 힐링받고 간다 이건 연인들 뿐만 아니라 가족 친구와 봐도 ...

# %% [markdown]
# 긍/부정 표시

# %%
import numpy as np

# %%
# score가 5보다 크면 1, 아니면 0
df['sentiment'] = np.where(df['score'] > 5, 1, 0)
df.head()
# Out:
#    score                                             review  sentiment
# 0      1                                 관람객 그냥 모르겠다 돈 아깝다           0
# 1     10   관람객 나도 모르는 사이에 작년에 많이 힘들었나봐요 카운트다운할때 울컥해요 올해는...          1
# 2      3                                    관람객 손발사라지는줄 오글           0
# 3     10             관람객 아르헨티나 장면들 힐링 2021년에는 행복한 일만 가득했으면           1
# 4     10   관람객 간만에 극장에서 힐링받고 간다 이건 연인들 뿐만 아니라 가족 친구와 봐도 ...          1

# %%
# 저장
df.to_csv('movie_review.csv', encoding='cp949', index=False)

# %%
# 불러오기
df = pd.read_csv('movie_review.csv', encoding='cp949')
df.head()
# Out:
#    score                                             review  sentiment
# 0      1                                 관람객 그냥 모르겠다 돈 아깝다           0
# 1     10   관람객 나도 모르는 사이에 작년에 많이 힘들었나봐요 카운트다운할때 울컥해요 올해는...          1
# 2      3                                    관람객 손발사라지는줄 오글           0
# 3     10             관람객 아르헨티나 장면들 힐링 2021년에는 행복한 일만 가득했으면           1
# 4     10   관람객 간만에 극장에서 힐링받고 간다 이건 연인들 뿐만 아니라 가족 친구와 봐도 ...          1

# %% [markdown]
# 한글, 알파벳, 숫자 제외한 문자 제거

# %%
import re

# %%
def remove_non_word(text):
    """한글, 알파벳, 숫자를 제외한 문자를 제거"""
    return re.sub(r'[^가-힣A-z0-9]+', ' ', text)

# %%
remove_non_word('Wow, 정말 1도 재미 없다!')
# Out:
# 'Wow 정말 1도 재미 없다 '

# %% [markdown]
# WPM(Word Piece Model) 학습
#  - 구글의 WPM에는 BPE(Byte Pair Encoding) 알고리즘
#     - 자연어 처리를 위한 주요 전처리 방법으로 사용

# %%
#!pip install subword-nmt
# Out:
# Collecting subword-nmt
#   Downloading subword_nmt-0.3.7-py2.py3-none-any.whl (26 kB)
# Installing collected packages: subword-nmt
# Successfully installed subword-nmt-0.3.7

# %%
from subword_nmt.learn_bpe import learn_bpe
import io

with open('영화평BPE.txt', 'w', encoding='utf8') as outfile:
    infile = io.StringIO(remove_non_word(' '.join(df['review'])))
    learn_bpe(infile, outfile, 1000)
# Out:
# no pair has frequency >= 2. Stopping

# %%
from subword_nmt.apply_bpe import BPE

with open('영화평BPE.txt', encoding='utf8') as f:
    bpe = BPE(f, separator='~')

# %% [markdown]
# TDM 만들기

# %% [markdown]
# - BoW(Bag of Words)란 단어들의 순서는 전혀 고려하지 않고, 단어들의 출현 빈도(frequency)에만 집중하는 텍스트 데이터의 수치화 표현 방법
# <img src="TDM.jpg">

# %%
def tokenizer_wpm(text):
    text = remove_non_word(text)
    tokens = bpe.process_line(text)
    tokens = tokens.split()
    return [t for t in tokens
            if (not t.endswith('~') and len(t) > 1) or len(t) > 2]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv_wpm = CountVectorizer(max_features=1000, tokenizer=tokenizer_wpm)

# %%
tdm = cv_wpm.fit_transform(df['review'])

# %% [markdown]
# 토큰 빈도

# %%
freq = pd.DataFrame({
    'word': cv_wpm.get_feature_names(),
    'n': tdm.sum(axis=0).flat
})
freq.head()
# Out:
#   word  n
# 0  100  2
# 1  10~  4
# 2  12월  6
# 3  1년~  2
# 4   1월  2

# %%
freq.sort_values('n').tail(10)
# Out:
#      word   n
# 385   습니다  20
# 727    진짜  21
# 791    하고  22
# 525  오랜만에  22
# 495   영화~  30
# 698    좋은  31
# 293    보기  41
# 130    너무  56
# 87    관람객  70
# 494    영화  72

# %% [markdown]
# 데이터 분할

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    tdm, df['sentiment'], test_size=.2, random_state=1234)

# %% [markdown]
# 학습

# %%
from sklearn.linear_model import LogisticRegressionCV
model = LogisticRegressionCV(random_state=1234)
model.fit(x_train, y_train)
# Out:
# LogisticRegressionCV(random_state=1234)

# %% [markdown]
# 성능 평가

# %%
from sklearn.metrics import accuracy_score
y_pred = model.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %% [markdown]
# 계수 분석

# %%
word_coef = pd.DataFrame({
    'word': cv_wpm.get_feature_names(),
    'coef': model.coef_.flat
})

# %%
word_coef.head()
# Out:
#   word      coef
# 0  100  0.000003
# 1  10~  0.000009
# 2  12월  0.000012
# 3  1년~  0.000006
# 4   1월  0.000003

# %%
word_coef.sort_values('coef', ascending=False).head(10)
# Out:
#      word      coef
# 494    영화  0.000157
# 698    좋은  0.000075
# 495   영화~  0.000072
# 791    하고  0.000054
# 727    진짜  0.000054
# 385   습니다  0.000048
# 525  오랜만에  0.000048
# 863   힐링~  0.000045
# 695  좋았어요  0.000039
# 130    너무  0.000039

# %%
word_coef.sort_values('coef').tail(10)
# Out:
#      word      coef
# 130    너무  0.000039
# 695  좋았어요  0.000039
# 863   힐링~  0.000045
# 525  오랜만에  0.000048
# 385   습니다  0.000048
# 727    진짜  0.000054
# 791    하고  0.000054
# 495   영화~  0.000072
# 698    좋은  0.000075
# 494    영화  0.000157
