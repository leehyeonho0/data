# %% [markdown]
# # 시각화
# ### matplotlib.pyplot

# %% [markdown]
# #### https://data.kma.go.kr/

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([10, 20, 30, 40])
plt.show()

# %%
plt.plot([1,2,3,4], [12, 43, 25, 15])
plt.show()

# x 축: [1,2,3,4]
# y 축: [12, 43, 25, 15]

# %% [markdown]
# ### 그래프에 옵션 추가하기

# %%
# 제목 추가
plt.title('plotting')
plt.plot([10, 20, 30, 40])
plt.show()

# %%
# 범례(legend) 추가 
plt.title('legend')
plt.plot([10, 20, 30, 40], label='asc')
plt.plot([40, 30, 20, 10], label='desc')
plt.legend() # 범례표시
plt.show()

# %%
# 선 스타일 변경
plt.title('linestyle')
plt.plot([10, 20, 30, 40], color='r', linestyle='--', label='dashed') # 빨간색 dashed 그래프
plt.plot([40, 30, 20, 10], color='g', ls=':', label='dotted') # 초록색 dotted 그래프
plt.legend() # 범례표시
plt.show()

# %%
# 마커 모양 바꾸기
plt.title('marker') # 제목설정
plt.plot([10, 20, 30, 40], 'r.', label='circle') # 빨간색 원형 마커 그래프
plt.plot([40, 30, 20, 10], 'g^', label='triangle up') # 초록색 삼각형 마커 그래프
plt.legend() # 범례표시
plt.show()

# %% [markdown]
# ### 예제로 실습하기

# %%
# 서울 데이터를 읽어오기
# 내 생일의 기온 변화를 그래프로 그리기

# %%
# 데이터 읽어오기
import csv
import matplotlib.pyplot as plt
f = open('seoul.csv')
data = csv.reader(f)
next(data) # 제목줄(첫칸) 없애기

for row in data :
    print(row)

f.close()
# Out:
# ['1907-10-01', '108', '13.5', '7.9', '20.7']
# ['1907-10-02', '108', '16.2', '7.9', '22']
# ['1907-10-03', '108', '16.2', '13.1', '21.3']
# ['1907-10-04', '108', '16.5', '11.2', '22']
# ['1907-10-05', '108', '17.6', '10.9', '25.4']
# ['1907-10-06', '108', '13', '11.2', '21.3']
# ['1907-10-07', '108', '11.3', '6.3', '16.1']
# ['1907-10-08', '108', '8.9', '3.9', '14.9']
# ['1907-10-09', '108', '11.6', '3.8', '21.1']
# ['1907-10-10', '108', '14.2', '6.4', '24.1']
# ['1907-10-11', '108', '15.4', '10.1', '20.4']
# ['1907-10-12', '108', '13.9', '11.1', '17.4']
# ['1907-10-13', '108', '13.8', '8.3', '21.3']
# ['1907-10-14', '108', '13', '6.1', '20.6']
# ['1907-10-15', '108', '13.1', '5.7', '20.9']
# ['1907-10-16', '108', '14.1', '8.2', '20.2']
# ['1907-10-17', '108', '16.4', '10.3', '21.6']
# ['1907-10-18', '108', '14.3', '9.8', '20.9']
# ['1907-10-19', '108', '13.9', '6.7', '21.3']
# ['1907-10-20', '108', '18.3', '12.4', '22.7']
# ['1907-10-21', '108', '15.2', '10.7', '19.9']
# ...

# %%
# 데이터의 맨 윗줄의 헤더 부분을 next() 함수를 사용해 제외하고 
# 최고기온 데이터만 출력하기
f = open('seoul.csv')
data = csv.reader(f)
next(data)

for row in data :
    print(row[-1])

f.close()
# Out:
# 20.7
# 22
# 21.3
# 22
# 25.4
# 21.3
# 16.1
# 14.9
# 21.1
# 24.1
# 20.4
# 17.4
# 21.3
# 20.6
# 20.9
# 20.2
# 21.6
# 20.9
# 21.3
# 22.7
# 19.9
# 19.6
# 16.3
# 17.1
# 18.7
# 18.2
# 20.7
# 19.6
# 20
# 20.1
# 20.3
# 21.3
# 21.1
# 11.1
# 13.6
# 17
# 18.1
# 12.4
# 9.4
# 11.9
# 13.2
# 13.4
# 14.9
# 16.4
# 15.2
# 17.6
# 12.6
# 11.7
# 6.7
# 4.3
# 7.1
# 6.2
# 11.2
# 9.9
# 5.9
# -0.7
# 1.5
# 1.9
# 2
# 2.9
# -2.4
# 1.4
# 3.4
# 6.1
# 1.3
# 2.6
# 5.8
# 1.9
# 6.6
# 8.1
# 4.3
# 0.6
# 3.8
# 9
# 6.4
# -5.1
# -2.4
# -2.1
# -0.4
# -0.2
# 1.9
# -8.1
# -10.2
# -9.4
# 0.9
# 6.8
# 6.4
# -0.7
# -1.9
# -4.4
# -6.1
# -2.1
# -1.3
# -3
# -2.9
# -1.7
# -0.1
# 2.9
# -1.2
# -0.9
# 2
# 3.3
# 4.8
# 4.5
# 4.7
# 0.1
# 0.9
# -4.5
# -3.6
# 2.8
# 2.8
# 2.3
# -6.1
# -5.1
# -2.7
# 0.1
# 0.3
# -0.6
# 0
# -1.3
# 0.8
# 0.8
# 6.2
# 1.6
# -0.2
# -5.4
# -4.1
# -5.5
# -5.7
# -3.7
# 1.3
# -4.1
# -2.5
# -2.8
# -1.2
# 1.3
# 2.3
# 2
# -1.4
# -1.6
# 0.3
# 5.5
# 7.3
# 5.1
# 5.4
# 2.7
# 1.7
# 0.8
# 4.1
# 8.4
# 6.3
# 5.6
# 4
# 0.1
# 4.9
# ...

# %%
# 데이터 리스트에 저장하기
import csv
f =open('seoul.csv')
data = csv.reader(f)
next(data)

result = [] # 최고 기온 데이터를 저장할 리스트 생성

for row in data :
    if row[-1] != '':  # 최고 기온 데이터 값이 존재한다면
        result.append(float(row[-1]))  # result 리스트에 최고 기온 값 추가
print(result)
        
f.close()
# Out:
# [20.7, 22.0, 21.3, 22.0, 25.4, 21.3, 16.1, 14.9, 21.1, 24.1, 20.4, 17.4, 21.3, 20.6, 20.9, 20.2, 21.6, 20.9, 21.3, 22.7, 19.9, 19.6, 16.3, 17.1, 18.7, 18.2, 20.7, 19.6, 20.0, 20.1, 20.3, 21.3, 21.1, 11.1, 13.6, 17.0, 18.1, 12.4, 9.4, 11.9, 13.2, 13.4, 14.9, 16.4, 15.2, 17.6, 12.6, 11.7, 6.7, 4.3, 7.1, 6.2, 11.2, 9.9, 5.9, -0.7, 1.5, 1.9, 2.0, 2.9, -2.4, 1.4, 3.4, 6.1, 1.3, 2.6, 5.8, 1.9, 6.6, 8.1, 4.3, 0.6, 3.8, 9.0, 6.4, -5.1, -2.4, -2.1, -0.4, -0.2, 1.9, -8.1, -10.2, -9.4, 0.9, 6.8, 6.4, -0.7, -1.9, -4.4, -6.1, -2.1, -1.3, -3.0, -2.9, -1.7, -0.1, 2.9, -1.2, -0.9, 2.0, 3.3, 4.8, 4.5, 4.7, 0.1, 0.9, -4.5, -3.6, 2.8, 2.8, 2.3, -6.1, -5.1, -2.7, 0.1, 0.3, -0.6, 0.0, -1.3, 0.8, 0.8, 6.2, 1.6, -0.2, -5.4, -4.1, -5.5, -5.7, -3.7, 1.3, -4.1, -2.5, -2.8, -1.2, 1.3, 2.3, 2.0, -1.4, -1.6, 0.3, 5.5, 7.3, 5.1, 5.4, 2.7, 1.7, 0.8, 4.1, 8.4, 6.3, 5.6, 4.0, 0.1, 4.9, 4.0, 7.9, 7.9, 2.2, 1.9, 1.5, 1.5, 1.8, 2.6, 3.8, 6.7, 11.8, 13.5, 15.7, 10.7, 7.9, 4.3, 6.0, 12.5, 17.0, 14.7, 11.4, 7.4, 8.0, 15.5
# ...

# %%
# 개수확인
print(len(result))
# Out:
# 40208

# %%
# 기상 관측 이래 서울의 최고 기온이 가장 높았던 날
import csv
max_temp =-999   # 최고 기온 값을 저장할 변수
max_date =''       # 최고 기온이 가장 높았던 날짜를 저장할 변수

f =open('seoul.csv')
data = csv.reader(f)
header =next(data)

for row in data :
    if row[-1] =='' :
        row[-1] =-999   # -999를 넣어 빈 문자열이 있던 자리라고 표시
    row[-1] = float(row[-1])
    
    if max_temp < row[-1] :
        max_date = row[0]
        max_temp = row[-1]

f.close()
print('기상 관측 이래 서울의 최고 기온이 가장 높았던 날은',max_date+'로, ', max_temp, '도 였습니다.')
# Out:
# 기상 관측 이래 서울의 최고 기온이 가장 높았던 날은 2018-08-01로,  39.6 도 였습니다.

# %%
# 최고 기온 데이터 꺽은 선으로 표현
import csv
import matplotlib.pyplot as plt
f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[-1] != '' :
        result.append(float(row[-1]))
        #print(float(row[-1]))

plt.plot(result, 'r') # result 리스트에 저장된 값을 빨간색 그래프로 그리기
plt.show() # 그래프 나타내기

# %%
# 결측치 있는 년도
import csv
import matplotlib.pyplot as plt
f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[-1] == '' :
        result.append(row[0])
print(result)
# Out:
# ['1950-09-01', '1950-09-02', '1950-09-03', '1950-09-04', '1950-09-05', '1950-09-06', '1950-09-07', '1950-09-08', '1950-09-09', '1950-09-10', '1950-09-11', '1950-09-12', '1950-09-13', '1950-09-14', '1950-09-15', '1950-09-16', '1950-09-17', '1950-09-18', '1950-09-19', '1950-09-20', '1950-09-21', '1950-09-22', '1950-09-23', '1950-09-24', '1950-09-25', '1950-10-01', '1950-10-02', '1950-10-03', '1950-10-04', '1950-10-05', '1950-10-06', '1950-10-07', '1950-10-08', '1950-10-09', '1950-10-10', '1950-10-11', '1950-10-12', '1950-10-13', '1950-10-14', '1950-10-15', '1950-10-16', '1950-10-17', '1950-10-18', '1950-10-19', '1950-10-20', '1950-10-21', '1950-10-22', '1950-10-23', '1950-10-24', '1950-10-25', '1950-10-26', '1950-10-27', '1950-10-28', '1950-10-29', '1950-10-30', '1950-10-31', '1951-12-01', '1951-12-02', '1951-12-03', '1951-12-04', '1951-12-05', '1951-12-06', '1951-12-07', '1951-12-08', '1951-12-09', '1951-12-10', '1951-12-11', '1951-12-12', '1951-12-13', '1951-12-14', '1951-12-15', '19
# ...

# %% [markdown]
# ### (참고) 판다스로 표현하기

# %%
import pandas as pd

# %%
seoul = pd.read_csv('seoul.csv', encoding='cp949')
seoul.head()
# Out:
#            날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  1907-10-01  108     13.5      7.9     20.7
# 1  1907-10-02  108     16.2      7.9     22.0
# 2  1907-10-03  108     16.2     13.1     21.3
# 3  1907-10-04  108     16.5     11.2     22.0
# 4  1907-10-05  108     17.6     10.9     25.4

# %%
#result = seoul['최고기온(℃)']
result = seoul.iloc[:, -1]
plt.plot(result, 'r') # result 리스트에 저장된 값을 빨간색 그래프로 그리기
plt.show() # 그래프 나타내기

# %%
import csv
import matplotlib.pyplot as plt
f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[-1] != '' :
        result.append(float(row[-1]))
        #print(float(row[-1]))
        
plt.figure(figsize = (10,2)) # 가로로 10인치, 세로로 2인치로 설정
#plt.figure(figsize = (10,2), dpi = 300)
plt.plot(result, 'r')
plt.show()

# %%
seoul.isnull().sum()
# Out:
# 날짜           0
# 지점           0
# 평균기온(℃)    756
# 최저기온(℃)    757
# 최고기온(℃)    758
# dtype: int64

# %%
seoul_new = seoul.copy()
seoul_new = seoul_new.dropna(subset=['평균기온(℃)', '최저기온(℃)','최고기온(℃)'])

# 데이터의 건수, 항목수를 확인
seoul_new.isnull().sum()
# Out:
# 날짜         0
# 지점         0
# 평균기온(℃)    0
# 최저기온(℃)    0
# 최고기온(℃)    0
# dtype: int64

# %%
#result = seoul['최고기온(℃)']
result = seoul_new.iloc[:, -1]
plt.plot(result, 'r') # result 리스트에 저장된 값을 빨간색 그래프로 그리기
plt.show() # 그래프 나타내기

# %%
s = 'hello python'
print(s)
# Out:
# hello python

# %%
date = '1907-10-01'
print(date.split('-'))
# Out:
# ['1907', '10', '01']

# %%
print(date.split('-')[0])
print(date.split('-')[1])
print(date.split('-')[2])
# Out:
# 1907
# 10
# 01

# %%
import csv

f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[-1] != '' :
        if row[0].split('-')[1] == '08' :  # 8월에 해당하는 값이라면
            result.append(float(row[-1]))

plt.plot(result, 'hotpink') # result 리스트에 저장된 값을 hotpink 색으로 그리기
plt.show()  # 그래프로 나타내기

# %%
# 매년 7월 2일의 최고 기온 데이터 추출 그래프로 나타내기

f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[-1] != '' :
        if row[0].split('-')[1] == '07' and row[0].split('-')[2] == '02' :
            result.append(float(row[-1]))

plt.plot(result, 'hotpink')
plt.show()

# %%
# 최고 기온과 최저기온을 함께 나타내기
f = open('seoul.csv')
data = csv.reader(f)
next(data)
high = []
low = []

for row in data :
    if row[-1] != '' and row[-2] != '' :
        if row[0].split('-')[1] == '07' and row[0].split('-')[2] == '02' :
            high.append(float(row[-1]))  # 최고기온 값을 high 리스트에 저장
            low.append(float(row[-2]))  # 최저 기온 값을 low 리스트에 저장

plt.plot(high, 'hotpink')
plt.plot(low, 'skyblue')
plt.show()

# %%
# 1983년 이후의 데이터만 추출해서 그리기
import csv

f = open('seoul.csv')
data = csv.reader(f)
next(data)
high = []
low = []

for row in data :
    if row[-1] != '' and row[-2] != '' :
        if 1983 <= int(row[0].split('-')[0]) :  # 1983년 이후 데이터 라면
            if row[0].split('-')[1] == '07' and row[0].split('-')[2] == '02' :
                high.append(float(row[-1]))
                low.append(float(row[-2]))

import matplotlib.pyplot as plt
#plt.figure(dpi = 300)
plt.plot(high, 'hotpink')
plt.plot(low, 'skyblue')
plt.show()

# %%
# 내 생일의 기온 변화를 그래프로 그리기
import csv

f = open('seoul.csv')
data = csv.reader(f)
next(data)
high = []
low = []

for row in data :
    if row[-1] != '' and row[-2] != '' :
        if 1983 <= int(row[0].split('-')[0]) :
            if row[0].split('-')[1] == '07' and row[0].split('-')[2] == '02' :
                high.append(float(row[-1]))
                low.append(float(row[-2]))
                plt.rc('font', family = 'Malgun Gothic') # 맑은 고딕을 기본 글꼴로 설정
import matplotlib.pyplot as plt
#plt.figure(dpi = 300)
plt.plot(high, 'hotpink')
plt.plot(low, 'skyblue')
plt.rc('font', family ='Malgun Gothic')
plt.title('내 생일의 기온 변화 그래프')
plt.show()

# %%
# plt.rc('font', family = 'Malgun Gothic') 추가

f = open('seoul.csv')
data = csv.reader(f)
next(data)
high = []
low = []

for row in data :
    if row[-1] != '' and row[-2] != '' :
        if 1983 <= int(row[0].split('-')[0]) :
            if row[0].split('-')[1] == '07' and row[0].split('-')[2] == '02' :
                high.append(float(row[-1]))
                low.append(float(row[-2]))

plt.rc('font', family = 'Malgun Gothic') # 맑은 고딕을 기본 글꼴로 설정                
plt.plot(high, 'hotpink')
plt.plot(low, 'skyblue')
plt.rc('font', family ='Malgun Gothic')
plt.title('내 생일의 기온 변화 그래프')
plt.show()

# %%
# plt.rcParams['axes.unicode_minus'] = False 추가

import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
high = [] # 최고 기온 값을 저장할 리스트 high 생성
low = [] # 최저 기온 값을 저장할 리스트 low 생성

for row in data :
    if row[-1] != '' and row[-2] != '' : # 최고 기온 값과 최저 기온 값이 존재한다면
        date = row[0].split('-') # 날짜 값을 – 문자를 기준으로 구분하여 저장
        if 1983 <= int(date[0]) : # 1983년 이후 데이터라면
            if date[1] == '07' and date[2] == '02' : # 7월 2일이라면
                high.append(float(row[-1])) # 최고 기온 값을 high 리스트에 저장
                low.append(float(row[-2])) # 최저 기온 값을 low 리스트에 저장

plt.rc('font', family = 'Malgun Gothic') # 맑은 고딕을 기본 글꼴로 설정
plt.rcParams['axes.unicode_minus'] = False # 마이너스 기호 깨짐 방지
plt.title('내 생일의 기온 변화 그래프') # 제목 설정
plt.plot(high, 'hotpink', label = 'high') # high 리스트에 저장된 값을 hotpink 색으로 그리고 레이블을 표시

plt.plot(low, 'skyblue', label = 'low') # low 리스트에 저장된 값을 skyblue 색으로 그리고 레이블을 표시
plt.legend() # 범례 표시
plt.show() # 그래프 나타내기

# %% [markdown]
# ### 히스토 그램

# %%
import matplotlib.pyplot as plt
#plt.figure(dpi = 100)  # 전체크기 조절
plt.hist([1,1,2,3,4,5,6,6,7,8,10])
plt.show()

# %% [markdown]
# ##### 주사위 시뮬레이션

# %%
import random
print(random.randint(1,6))
# Out:
# 5

# %%
import random
for i in range(5) :
    print(random.randint(1,6))
# Out:
# 5
# 3
# 6
# 6
# 2

# %%
import random
dice = []
for i in range(5) :
    dice.append(random.randint(1,6))
print(dice)
# Out:
# [5, 4, 2, 1, 4]

# %%
import random
dice = []
for i in range(5) :
    dice.append(random.randint(1,6))
print(dice)

import matplotlib.pyplot as plt
#plt.figure(dpi = 300)
plt.hist(dice, bins = 12)  # 막대그래프 사이즈
plt.show()
# Out:
# [1, 6, 6, 2, 5, 1, 2, 6, 3, 5, 4, 1, 2, 4, 6, 1, 5, 4, 4, 1, 2, 6, 1, 5, 2, 1, 5, 6, 2, 3, 3, 3, 6, 1, 6, 1, 5, 6, 5, 3, 5, 4, 2, 3, 6, 2, 6, 2, 6, 5, 3, 1, 3, 2, 3, 2, 3, 2, 3, 1, 5, 1, 1, 6, 1, 4, 4, 3, 3, 4, 6, 3, 1, 3, 6, 6, 3, 3, 2, 3, 6, 3, 6, 2, 5, 6, 5, 6, 6, 5, 3, 2, 1, 4, 1, 1, 1, 3, 4, 1]

# %%
import random
dice = []
for i in range(100) :
    dice.append(random.randint(1,6))
#print(dice)

import matplotlib.pyplot as plt
#plt.figure(dpi = 300)
plt.hist(dice, bins = 12)
plt.show()

# %%
import random
dice = []
for i in range(1000000) :  # 주사위를 백만번 돌렸을때
    dice.append(random.randint(1,6))

import matplotlib.pyplot as plt
#plt.figure(dpi = 300)
plt.hist(dice, bins = 6)
plt.show()

# %% [markdown]
# ##### 기온데이터를 히스토 그램으로 표현하기

# %%
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[-1] != '' :
        result.append(float(row[-1]))

import matplotlib.pyplot as plt
#plt.figure(dpi = 300)
plt.hist(result, bins = 100, color = 'r')
plt.show()

# %%
plt.figure(dpi = 300)
plt.hist(result, bins = 1000, color = 'r')
plt.show()

# %%
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)
aug = []

for row in data :
    #print(row[0])
    month = row[0].split('-')[1]  # -로 구분된 값 중 2번째 값을 month에 저장
    #print(month)
    if row[-1] != '' :
        if month == '08':
            aug.append(float(row[-1]))
print(aug)
# Out:
# [29.6, 30.7, 32.0, 31.5, 32.4, 33.6, 30.9, 29.5, 26.7, 26.8, 30.5, 30.5, 29.0, 28.9, 30.4, 31.7, 32.0, 33.3, 32.5, 33.5, 31.1, 26.7, 26.1, 27.5, 23.9, 21.3, 23.3, 26.0, 27.7, 27.9, 27.2, 32.3, 27.5, 31.7, 33.2, 34.5, 31.7, 30.2, 35.6, 34.8, 33.0, 30.8, 27.8, 24.8, 23.9, 23.8, 25.3, 27.3, 28.3, 30.3, 30.3, 30.0, 30.0, 27.7, 30.9, 25.3, 26.8, 29.1, 30.5, 30.6, 29.5, 26.5, 32.0, 31.6, 31.4, 31.2, 32.0, 29.9, 29.0, 30.3, 30.6, 30.6, 31.5, 31.0, 30.6, 29.5, 27.4, 28.1, 27.4, 28.4, 25.2, 29.5, 26.5, 29.0, 28.9, 29.0, 31.5, 31.2, 26.0, 23.9, 27.8, 29.0, 25.4, 31.0, 29.0, 30.5, 29.5, 28.8, 27.5, 31.4, 32.0, 33.0, 33.8, 32.9, 34.5, 33.8, 31.7, 32.5, 32.4, 33.5, 32.4, 28.0, 32.2, 30.1, 30.5, 30.1, 22.8, 24.0, 28.4, 28.5, 29.5, 31.1, 31.5, 31.0, 31.5, 32.0, 32.2, 32.7, 34.0, 31.0, 30.9, 31.0, 32.2, 33.2, 33.0, 31.3, 30.6, 31.5, 30.3, 24.9, 24.9, 21.5, 20.3, 23.4, 27.2, 26.9, 29.0, 29.5, 28.5, 27.5, 28.5, 28.2, 29.2, 29.3, 29.4, 31.7, 31.5, 28.9, 29.3, 29.0, 29.8, 31.5, 31.7, 30.1, 28.9, 27.8, 2
# ...

# %%
# 8월의 데이터만 뽑아서 히스토그램으로 그리기
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)
aug = []

for row in data :
    month = row[0].split('-')[1]  # -로 구분된 값 중 2번째 값을 month에 저장
    if row[-1] != '' :
        if month == '08':
            aug.append(float(row[-1]))

import matplotlib.pyplot as plt
#plt.figure(dpi = 300)
plt.hist(aug, bins = 100, color = 'r')
plt.show()

# 정규분포 모양으로 나타남을 알 수 있다.
# 8월에는 30도 정도였던 날이 가장 많았다.
# 최고기온이 20도 이하였거나 40도 이상인 적은 거의 없었음을 알 수 있다.

# %%
# 1월과 8월의 데이터를 히스토 그램으로 시각화 하기
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)
aug = []
jan = []

for row in data :
    month = row[0].split('-')[1]
    if row[-1] != '' :
        if month == '08':
            aug.append(float(row[-1]))
        if month == '01':
            jan.append(float(row[-1]))

import matplotlib.pyplot as plt
#plt.figure(dpi = 300)
plt.hist(aug, bins = 100, color = 'r', label = 'Aug')
plt.hist(jan, bins = 100, color = 'b', label = 'Jan')
plt.legend()
plt.show()

# %% [markdown]
# ### boxplot(상자그림)으로 표현하기

# %%
import matplotlib.pyplot as plt
#plt.figure(dpi = 300)
import random
result = []
for i in range(13) :
    result.append(random.randint(1,1000))  # 1 ~ 1000 까지의 임의의 데이터를 만든다.
print(sorted(result))
#import numpy as np
#result = np.array(result)
#print("1/4: " + str(np.percentile(result,25)))
#print("2/4: " + str(np.percentile(result,50)))
#print("3/4: " + str(np.percentile(result,75)))
plt.boxplot(result)
plt.show()
# Out:
# [31, 43, 314, 316, 318, 346, 347, 403, 475, 482, 505, 704, 764]

# %%
# 다른 위치의 값을 알고 싶을때
import matplotlib.pyplot as plt
#plt.figure(dpi = 300)
import random
result = []
for i in range(13) :
    result.append(random.randint(1,1000))  # 1 ~ 1000 까지의 임의의 데이터를 만든다.
print(sorted(result))
import numpy as np
result = np.array(result)
print("1/4: " + str(np.percentile(result,25)))
print("2/4: " + str(np.percentile(result,50)))
print("3/4: " + str(np.percentile(result,75)))
plt.boxplot(result)
plt.show()
# Out:
# [21, 60, 95, 255, 303, 309, 348, 412, 552, 661, 691, 773, 874]
# 1/4: 255.0
# 2/4: 348.0
# 3/4: 661.0

# %%
# 서울의 최고 기온데이터를 상자그림으로 표현하기
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[-1] != '' :
        result.append(float(row[-1]))

import matplotlib.pyplot as plt
#plt.figure(dpi = 300)

import numpy as np
result = np.array(result)
print("1/4: " + str(np.percentile(result,25)))
print("2/4: " + str(np.percentile(result,50)))
print("3/4: " + str(np.percentile(result,75)))

plt.boxplot(result)
plt.show()
# Out:
# 1/4: 7.2
# 2/4: 18.6
# 3/4: 26.3

# %%
# 1월과 8월의 상자그림을 함께 표현하기
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)
aug = []
jan = []

for row in data :
    month = row[0].split('-')[1]
    if row[-1] != '' :
        if month == '08':
            aug.append(float(row[-1]))
        if month == '01':
            jan.append(float(row[-1]))

import matplotlib.pyplot as plt
#plt.figure(dpi = 300)
plt.boxplot(aug)
plt.boxplot(jan)
plt.show()

# %%
# 1월과 8월의 상자그림을 리스트로 함께 표현하기
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)
aug = []
jan = []

for row in data :
    month = row[0].split('-')[1]
    if row[-1] != '' :
        if month == '08':
            aug.append(float(row[-1]))
        if month == '01':
            jan.append(float(row[-1]))

import matplotlib.pyplot as plt
#plt.figure(dpi = 300)
plt.boxplot([aug,jan])
plt.show()

# %%
# 최고기온 데이터를 월별로 구분하여 표현하기
import matplotlib.pyplot as plt
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)

# 월별 데이터를 저장할 리스트 month 생성(12개)
month = [[],[],[],[],[],[],[],[],[],[],[],[]]

for row in data :
    if row[-1] != '' :
        # 월과 같은 번호의 인덱스에 월별 데이터 저장(예: 1월 - month[0])
        month[int(row[0].split('-')[1])-1].append(float(row[-1]))
print(month)
# Out:
# [[-1.3, -3.0, -2.9, -1.7, -0.1, 2.9, -1.2, -0.9, 2.0, 3.3, 4.8, 4.5, 4.7, 0.1, 0.9, -4.5, -3.6, 2.8, 2.8, 2.3, -6.1, -5.1, -2.7, 0.1, 0.3, -0.6, 0.0, -1.3, 0.8, 0.8, 6.2, -3.5, 2.5, 5.0, 7.6, 4.7, 1.5, 1.4, -0.1, 0.3, 1.5, 3.3, 1.9, 0.2, 3.0, 2.1, 1.7, 5.5, 5.2, 2.8, 0.2, -2.2, -2.3, 0.7, 4.5, 2.9, 2.2, 0.0, 2.0, 1.5, 1.4, 4.7, 0.6, -4.3, 3.4, 8.0, 7.5, 7.7, 6.8, 5.7, 1.9, 4.5, 7.4, 5.4, 6.9, 6.6, -0.3, -5.2, -6.0, -3.0, -0.1, 4.6, 2.8, 1.3, 0.6, -1.2, -0.6, 2.8, 3.3, 3.2, 0.1, -1.6, -11.0, -6.5, -5.9, -1.4, 2.2, 1.7, -5.6, -3.8, 2.0, 0.7, 5.5, -1.2, -11.6, -9.2, -0.3, -1.3, 0.3, 0.0, 0.5, 1.7, 2.4, 1.1, -1.0, -6.9, -3.0, -1.6, 3.7, 4.7, 7.5, 8.8, 8.2, 7.1, 4.2, -5.4, -2.5, 0.3, 5.1, 4.7, 2.8, 2.5, 2.7, -0.4, -3.3, -3.2, -4.6, -2.2, -4.3, -4.3, -0.5, 1.3, -0.5, 1.2, 0.2, 0.1, 0.6, 3.5, 3.4, 5.4, 4.0, 1.8, -1.5, -0.2, 2.2, -4.2, 1.0, 6.3, -1.3, -7.3, -4.6, -0.6, 3.1, 3.5, -1.3, -2.6, -6.3, -5.1, -4.2, 1.3, 5.1, 2.7, 0.8, -0.6, 3.6, 4.5, 4.6, -0.4, -3.5, -4.0, -2.3, -0.5, 2.4, -0.7, -3
# ...

# %%
# 최고기온 데이터를 월별로 구분하여 표현하기
import matplotlib.pyplot as plt
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)

# 월별 데이터를 저장할 리스트 month 생성(12개)
month = [[],[],[],[],[],[],[],[],[],[],[],[]]

for row in data :
    if row[-1] != '' :
        # 월과 같은 번호의 인덱스에 월별 데이터 저장(예: 1월 - month[0])
        month[int(row[0].split('-')[1])-1].append(float(row[-1]))
        
#plt.figure(figsize=(10,5), dpi=300)
plt.boxplot(month)
plt.show()

# %%
# 8월 일별 기온 데이터를 상자 그림으로 표현하기
import matplotlib.pyplot as plt
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)

day = []  # 일별 데이터를 저장할 리스트 day 생성
for i in range(31) :   # day 리스트 내 31개 리스트 생성
    day.append([])

for row in data :
    if row[-1] != '' :
        if row[0].split('-')[1] == '08':
            print(row[0])
# Out:
# 1908-08-01
# 1908-08-02
# 1908-08-03
# 1908-08-04
# 1908-08-05
# 1908-08-06
# 1908-08-07
# 1908-08-08
# 1908-08-09
# 1908-08-10
# 1908-08-11
# 1908-08-12
# 1908-08-13
# 1908-08-14
# 1908-08-15
# 1908-08-16
# 1908-08-17
# 1908-08-18
# 1908-08-19
# 1908-08-20
# 1908-08-21
# 1908-08-22
# 1908-08-23
# 1908-08-24
# 1908-08-25
# 1908-08-26
# 1908-08-27
# 1908-08-28
# 1908-08-29
# 1908-08-30
# 1908-08-31
# 1909-08-01
# 1909-08-02
# 1909-08-03
# 1909-08-04
# 1909-08-05
# 1909-08-06
# 1909-08-07
# 1909-08-08
# 1909-08-09
# 1909-08-10
# 1909-08-11
# 1909-08-12
# 1909-08-13
# 1909-08-14
# 1909-08-15
# 1909-08-16
# 1909-08-17
# 1909-08-18
# 1909-08-19
# 1909-08-20
# 1909-08-21
# 1909-08-22
# 1909-08-23
# 1909-08-24
# 1909-08-25
# 1909-08-26
# 1909-08-27
# 1909-08-28
# 1909-08-29
# 1909-08-30
# 1909-08-31
# 1910-08-01
# 1910-08-02
# 1910-08-03
# 1910-08-04
# 1910-08-05
# 1910-08-06
# 1910-08-07
# 1910-08-08
# 1910-08-09
# 1910-08-10
# 1910-08-11
# 1910-08-12
# 1910-08-13
# 1910-08-14
# ...

# %%
# 8월 일별 기온 데이터를 상자 그림으로 표현하기
import matplotlib.pyplot as plt
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)

day = []  # 일별 데이터를 저장할 리스트 day 생성
for i in range(31) :   # day 리스트 내 31개 리스트 생성
    day.append([])

for row in data :
    if row[-1] != '' :
        if row[0].split('-')[1] == '08':
            day[int(row[0].split('-')[2])-1].append(float(row[-1])) # 최고 기온값 저장

#plt.boxplot(day)
plt.boxplot(day, showfliers=False) # 아웃라이어 값 생략
plt.show()

# %%
# ggplot으로 그래프 스터일 지정

import matplotlib.pyplot as plt
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)

day = [[] for i in range(31)]

for row in data :
    if row[-1] != '' :
        if row[0].split('-')[1] == '08':
            day[int(row[0].split('-')[2])-1].append(float(row[-1]))
        
plt.style.use('ggplot')  # 그래프 스타일 지정
plt.figure(figsize=(10,5), dpi=300)  # 그래프 크기 수정
plt.boxplot(day, showfliers=False)  # 아웃라이어 값 생략
plt.show()
